# %% [markdown]
# # Ejercicio de regresión lineal
#
# **Autor:** Jazna Meza Hidalgo
#
# **Correo Electrónico:** ymeza@ubiobio.cl
#
# **Fecha de Creación:** Abril de 2026
# **Versión:** 1.0
#
# ---
#
# ## Descripción
#
# Este notebook cumple con el objetivo de poner en práctica la creación de un modelo predictivo para una variable continua.
#
# Se debe aplicar el uso de pipeline como buena práctica de la industria.
#
#
# ---
#
# ## Requisitos de Software
#
# Este notebook fue desarrollado con Python 3.12. A continuación se listan las bibliotecas necesarias:
#
# - pandas (>=1.1.0)
# - matplotlib (3.7.1)
# - numpy (2.0.2)
#
#
# Para verificar la versión instalada ejecutar usando el siguiente comando, usando la librería de la cual quieres saber la versión:
#
# ```python
# import pandas as pd
# print(pd.__version__)
# ````

# %% [markdown]
# # Carga de datos

# %%
# !wget https://raw.githubusercontent.com/JaznaLaProfe/datos/master/regresion/dataset_regresion_practica.csv
# Out:
# --2026-04-25 01:04:04--  https://raw.githubusercontent.com/JaznaLaProfe/datos/master/regresion/dataset_regresion_practica.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58597 (57K) [text/plain]
# Saving to: ‘dataset_regresion_practica.csv’
#
# dataset_regresion_p 100%[===================>]  57.22K  --.-KB/s    in 0.01s
#
# 2026-04-25 01:04:04 (4.94 MB/s) - ‘dataset_regresion_practica.csv’ saved [58597/58597]

# %% [markdown]
# # Metadata
# 1. **ID**
#
# Tipo: Entero
#
# Rol: Identificador único (no necesariamente limpio debido a duplicados)
#
# Descripción: Identificador del registro
#
# 2. **Age**
#
# Tipo: Numérica (entera)
#
# Unidad: Años
#
# Descripción: Edad del trabajador
#
# Rango esperado: 18 – 70
#
# 3. **Income**
#
# Tipo: Numérica (continua)
#
# Unidad: Miles de unidades monetarias (escala relativa)
#
# Descripción: Ingreso mensual estimado
#
# 4. **Experience_Years**
#
# Tipo: Numérica (entera)
#
# Unidad: Años
#
# Descripción: Años de experiencia laboral
#
# 5. **Education_Level**
#
# Tipo: Categórica
#
# Descripción: Nivel educacional del trabajador
#
# 6. **City**
#
# Tipo: Categórica
#
# Descripción: Ciudad de residencia
#
# 7. **Work_Hours_Per_Week**
#
# Tipo: Numérica (entera)
#
# Unidad: Horas/semana
#
# Descripción: Cantidad de horas trabajadas semanalmente
#
# 8. **Remote_Work**
#
# Tipo: Categórica (binaria)
#
# Descripción: Indica si el trabajador realiza trabajo remoto
#
# 9. **Productivity_Score**
#
# Tipo: Numérica (continua)
#
# Descripción: Puntaje de productividad del trabajador

# %% [markdown]
# # Requisitos a cubrir

# %% [markdown]
# + Identificación del problema de negocio que puede ser cubierto con el modelo predictivo
# + Análisis de la calidad de los datos, incluyendo hallazgos
# + Incluir ingeniería de caraterísticas
# + Calcular e interpretar las métricas $R^2$ y MAE
# + Reflexión acerca de: ¿El modelo es confiable? y ¿Qué variables influyen más en la predicción?

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score

from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, FunctionTransformer, StandardScaler

from sklearn.base import BaseEstimator, TransformerMixin

# %%
data = pd.read_csv('dataset_regresion_practica.csv')
data.head()
# Out:
#    ID  Age   Income  Experience_Years Education_Level        City  \
# 0   1   56  1226.46                12             PhD  Valparaíso
# 1   2   69   791.92                37        Bachelor  Valparaíso
# 2   3   46  1007.04                 7             phd  Concepcion
# 3   4   32  1052.47                19        Bachelor  Concepción
# 4   5   60   675.79                32       Bachelors         NaN
#
#    Work_Hours_Per_Week Remote_Work  Productivity_Score
# 0                   43          no              423.00
# 1                   26         yes              231.16
# 2                   38         Yes              332.17
# 3                   41          no              282.51
# 4                   54         Yes              197.29

# %% [markdown]
# ## Objetivo de predicción

# %% [markdown]
# Predecir el puntaje de productividad (`Productivity_Score`), considerando `algunas` de las variables disponibles.

# %% [markdown]
# # Fase 2 - Entendimiento de los datos

# %% [markdown]
# # Fase 3 - Preparación de datos

# %% [markdown]
# # Fase 4 - Modelamiento
